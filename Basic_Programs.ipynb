# %% [markdown]
# <a href="https://colab.research.google.com/github/Srinivas-8612/Soft_Computing/blob/main/Basic_Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = input('Enter first number: ')
num2 = input('Enter second number: ')


sum = float(num1) + float(num2)


print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# Enter first number: 7
# Enter second number: 8
# The sum of 7 and 8 is 15.0

# %%
num = float(input('Enter a number: '))

num_sqrt = num ** 0.5
print('The square root of %0.3f is %0.3f'%(num ,num_sqrt))
# Out:
# Enter a number: 4
# The square root of 4.000 is 2.000

# %%
a = float(input('Enter first side: '))
b = float(input('Enter second side: '))
c = float(input('Enter third side: '))

s = (a + b + c) / 2


area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
print('The area of the triangle is %0.2f' %area)
# Out:
# Enter first side: 2
# Enter second side: 3
# Enter third side: 4
# The area of the triangle is 2.90

# %%
a = float(input('Enter first variable: '))
b = float(input('Enter second variable: '))
c = float(input('Enter third variable: '))

d = ((b**2) - (4*a*c))**0.5

sol1 = (-b-d)/(2*a)
sol2 = (-b+d)/(2*a)

print('The solution are {0} and {1}'.format(sol1,sol2))
# Out:
# Enter first variable: 1
# Enter second variable: 5
# Enter third variable: 6
# The solution are -3.0 and -2.0

# %%
x = input('Enter value of x: ')
y = input('Enter value of y: ')


temp = x
x = y
y = temp

print('x= {}'.format(x))
print('y= {}'.format(y))
# Out:
# Enter value of x: 12
# Enter value of y: 6
# x= 6
# y= 12

# %%
num = float(input("Enter a number: "))
if num > 0:
   print("Positive number")
elif num == 0:
   print("Zero")
else:
   print("Negative number")
# Out:
# Enter a number: -8
# Negative number

# %%
num = int(input("Enter a number: "))
if (num % 2) == 0:
   print("{0} is Even".format(num))
else:
   print("{0} is Odd".format(num))
# Out:
# Enter a number: 9
# 9 is Odd

# %%
y = int(input("Enter a year: "))


if (y % 400 == 0) and (y % 100 == 0):
    print("{0} is a leap year".format(y))

elif (y % 4 ==0) and (y % 100 != 0):
    print("{0} is a leap year".format(y))

else:
    print("{0} is not a leap year".format(y))
# Out:
# Enter a year: 2026
# 2026 is not a leap year

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

if (num1 >= num2) and (num1 >= num3):
   largest = num1
elif (num2 >= num1) and (num2 >= num3):
   largest = num2
else:
   largest = num3

print("The largest number is", largest)
# Out:
# Enter first number: 5
# Enter second number: 8
# Enter third number: 16
# The largest number is 16.0

# %%
num = float(input("Enter a number: "))
if num < 0:
   print("Enter a positive number")
else:
   sum = 0
   while(num > 0):
       sum = sum+num
       num = num-1
   print("The sum is", sum)
# Out:
# Enter a number: 17
# The sum is 153.0
